# %% [markdown]
# # Question 1:

# %%
a <- c(2.23, 3.45, 1.87, 2.11, 7.33, 18.34, 19.23)

# %%
mean(a)
# Out:
# [1] 7.794286

# %% [markdown]
# # Question 2:

# %%
sequence = seq(1, 25)
ans = 0
for (i in sequence){
    ans = ans + i^2
}

# %%
ans
# Out:
# [1] 5525

# %% [markdown]
# # Question 3:

# %%
class(cars)
# Out:
# [1] "data.frame"

# %% [markdown]
# # Question 4:

# %%
nrow(cars)
# Out:
# [1] 50

# %% [markdown]
# # Question 5:

# %%
head(cars)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10

# %% [markdown]
# # Question 6:

# %%
a <- cars[ ,2] # Indexing occurs as rows x columns.

# %%
mean(a)
# Out:
# [1] 42.98

# %% [markdown]
# # Question 7:

# %%
# The which function requires a logical array (consists of true and false):
which(cars[,2] == 85)
# Out:
# [1] 50

# %%
# Returns the row consisting of true.

# %%
# Learning above commands:
?read.csv
# Out:
# read.table                package:utils                R Documentation
#
# t
#
# n:
#
#      Reads a file in table format and creates a data frame from it,
#      with cases corresponding to lines and variables to fields in the
#      file.
#
# e:
#
#      read.table(file, header = FALSE, sep = "", quote = "\"'",
#                 dec = ".", numerals = c("allow.loss", "warn.loss", "no.loss"),
#                 row.names, col.names, as.is = !stringsAsFactors,
#                 na.strings = "NA", colClasses = NA, nrows = -1,
#                 skip = 0, check.names = TRUE, fill = !blank.lines.skip,
#                 strip.white = FALSE, blank.lines.skip = TRUE,
#                 comment.char = "#",
#                 allowEscapes = FALSE, flush = FALSE,
#                 stringsAsFactors = FALSE,
#                 fileEncoding = "", encoding = "unknown", text, skipNul = FALSE)
#
#      read.csv(file, header = TRUE, sep = ",", quote = "\"",
# ...
