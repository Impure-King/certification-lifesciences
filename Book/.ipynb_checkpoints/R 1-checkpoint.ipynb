# %%
# R is a bit more native, so no imports needed.

# %%
seq(1, 10) -> time # Mathematically, [1, 10]
2 * time + 10 -> distance

# %%
plot(time, distance, type='l', xlab="time", ylab="distance")
# Out:
# plot without title
